# %% [markdown]
# ## Import Data CSV as a Pandas DataFrame

# %%
import pandas as pd
import os

clean_data = pd.read_csv(os.path.join('..','data','vets_by_state_clean.csv'))

# %% [markdown]
# ### Show Data

# %%
clean_data.head()
# Out:
#         STATE  18 to 34 years  35 to 54 years  55 to 64 years  65 to 74 years  \
# 0     Alabama            14.5            47.8            41.9            53.9
# 1      Alaska            32.2            62.7            42.8            43.5
# 2     Arizona            12.9            39.9            34.4            61.9
# 3    Arkansas            18.3            46.6            38.0            53.0
# 4  California            16.2            38.4            34.1            59.2
#
#    75 years and over  Bachelor Degree or Higher*  \
# 0               42.0                        53.5
# 1               18.6                        58.3
# 2               50.8                        57.1
# 3               44.2                        42.7
# 4               52.2                        60.1
#
#    Below Poverty Level-Past 12 Months Income  \
# 0                                       14.0
# 1                                        9.3
# 2                                       15.0
# 3                                       19.7
# 4                                       14.9
#
#    Disability Rate- with Any Disability  \
# 0                                  67.0
# 1                                  46.8
# 2                                  61.2
# 3                                  67.8
# 4                                  60.7
#
#    Gulf War I                     (8/1990 to 8/2001)      ...       \
# 0                                               44.0      ...
# 1                                               57.6      ...
# 2                                               34.5      ...
# 3                                               36.3      ...
# 4                                               29.0      ...
#
#    High School Graduate or Equivalent*  Korean War  \
# 0                                 58.3        17.2
# 1                                 48.0         7.2
# 2                                 47.9        22.7
# 3                                 66.6        17.9
# 4                                 42.8        22.9
#
#    Less than High School Graduate*  Median Personal Income- Past 12 Months  \
# 0                             14.1                                 75591.0
# 1                              5.3                                103494.0
# 2                             10.2                                 72789.0
# 3                             17.8                                 62415.0
# 4                             12.0                                 81743.0
#
#    Percent Female  Some College*  Unemployment Rate for Veterans  \
# 0            17.2           74.2                             8.9
# 1            23.5           88.4                             9.6
# 2            14.5           84.7                             9.6
# 3            16.4           72.9                            10.3
# 4            13.5           85.2                            12.7
#
#    Veteran Population  Vietnam Era  World War II
# 0            331505.0         77.3           6.2
# 1             66785.0         68.8           1.8
# 2            488758.0         80.1           8.4
# 3            206940.0         74.7           8.7
# 4           1644215.0         79.4          10.9
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Create Scatter Matrix for Relevant Columns

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
subset = clean_data.iloc[:,[6,7,8]]
subset.columns = ['Disability\nRate', "Below Poverty Level\nIncome", "Bachelor's\nAttainment"]
pd.plotting.scatter_matrix(
    subset, alpha=0.7, 
    figsize=(9, 9), diagonal='hist'
)
plt.suptitle("Scatter Matrix of Several Important Variables")
plt.show()

# %% [markdown]
# ### Show Boxplot of The same set of variables

# %%
with plt.style.context(('ggplot')):
    axis = subset.plot(kind="box")
plt.show()
